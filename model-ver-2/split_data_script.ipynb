# %%
import torch
from model import *
from get_loader import get_loader
import torchvision.transforms as transforms
from PIL import Image
from IPython import display
import pandas as pd

# %%
data = pd.read_csv("archive/captions.txt")

# %%
data
# Out:
#                            image  \
# 0      1000268201_693b08cb0e.jpg
# 1      1000268201_693b08cb0e.jpg
# 2      1000268201_693b08cb0e.jpg
# 3      1000268201_693b08cb0e.jpg
# 4      1000268201_693b08cb0e.jpg
# ...                          ...
# 40450   997722733_0cb5439472.jpg
# 40451   997722733_0cb5439472.jpg
# 40452   997722733_0cb5439472.jpg
# 40453   997722733_0cb5439472.jpg
# 40454   997722733_0cb5439472.jpg
#
#                                                  caption
# 0      A child in a pink dress is climbing up a set o...
# 1                  A girl going into a wooden building .
# 2       A little girl climbing into a wooden playhouse .
# 3      A little girl climbing the stairs to her playh...
# 4      A little girl in a pink dress going into a woo...
# ...                                                  ...
# 40450           A man in a pink shirt climbs a rock face
# 40451           A man is rock climbing high in the air .
# 40452  A person in a red shirt climbing up a rock fac...
# 40453                    A rock climber in a red shirt .
# 40454  A rock climber practices on a rock climbing wa...
#
# [40455 rows x 2 columns]

# %%
training_data = data[:int(len(data) * 0.8) + 1]
testing_data = data.drop(training_data.index)

print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")
# Out:
# No. of training examples: 32365
# No. of testing examples: 8090

# %%
training_data
# Out:
#                            image  \
# 0      1000268201_693b08cb0e.jpg
# 1      1000268201_693b08cb0e.jpg
# 2      1000268201_693b08cb0e.jpg
# 3      1000268201_693b08cb0e.jpg
# 4      1000268201_693b08cb0e.jpg
# ...                          ...
# 32360  3601569729_bf4bf82768.jpg
# 32361  3601569729_bf4bf82768.jpg
# 32362  3601569729_bf4bf82768.jpg
# 32363  3601569729_bf4bf82768.jpg
# 32364  3601569729_bf4bf82768.jpg
#
#                                                  caption
# 0      A child in a pink dress is climbing up a set o...
# 1                  A girl going into a wooden building .
# 2       A little girl climbing into a wooden playhouse .
# 3      A little girl climbing the stairs to her playh...
# 4      A little girl in a pink dress going into a woo...
# ...                                                  ...
# 32360  A group of race horses run down a track carryi...
# 32361                                     A horse race .
# 32362                  Jockeys on horses during a race .
# 32363  The horses race on the dirt track while their ...
# 32364  There are riders and horses in a horse race , ...
#
# [32365 rows x 2 columns]

# %%
testing_data
# Out:
#                            image  \
# 32365  3601803640_5f3cb05acf.jpg
# 32366  3601803640_5f3cb05acf.jpg
# 32367  3601803640_5f3cb05acf.jpg
# 32368  3601803640_5f3cb05acf.jpg
# 32369  3601803640_5f3cb05acf.jpg
# ...                          ...
# 40450   997722733_0cb5439472.jpg
# 40451   997722733_0cb5439472.jpg
# 40452   997722733_0cb5439472.jpg
# 40453   997722733_0cb5439472.jpg
# 40454   997722733_0cb5439472.jpg
#
#                                                  caption
# 32365                        A man and a woman kissing .
# 32366  A man and woman kissing in front of a crowd of...
# 32367                         a man is kissing a woman .
# 32368  A young couple kiss while a crowd mills in the...
# 32369                     Two people kiss near a crowd .
# ...                                                  ...
# 40450           A man in a pink shirt climbs a rock face
# 40451           A man is rock climbing high in the air .
# 40452  A person in a red shirt climbing up a rock fac...
# 40453                    A rock climber in a red shirt .
# 40454  A rock climber practices on a rock climbing wa...
#
# [8090 rows x 2 columns]

# %%
training_data.to_csv("archive/training_captions.txt")
testing_data.to_csv("archive/testing_captions.txt")
